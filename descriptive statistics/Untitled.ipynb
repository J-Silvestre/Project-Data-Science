# %%
# import libraries ---------------------------------------------------------------------
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 

listingsUpdate = pd.read_csv("C:\\Users\\Rosan\\Documents\\GitHub\\listing_update\\listing_update.csv", sep='\t')
listingsUpdate.head()
# Out:
#    Unnamed: 0     id  host_id neighbourhood_group      neighbourhood  \
# 0           1  25659   107347              Lisboa  Santa Maria Maior
# 1           2  29248   125768              Lisboa  Santa Maria Maior
# 2           3  29396   126415              Lisboa  Santa Maria Maior
# 3           4  29720   128075              Lisboa            Estrela
# 4           5  29915   128890              Lisboa     Avenidas Novas
#
#    latitude  longitude  room_type  price  minimum_nights  ...  \
# 0  38.71241   -9.12706          4     50               2  ...
# 1  38.71082   -9.12719          4     60               5  ...
# 2  38.71156   -9.12987          4     60               2  ...
# 3  38.71108   -9.15979          4    957               2  ...
# 4  38.74571   -9.15264          4     50               5  ...
#
#    host_is_superhost  nr_of_bathrooms  bedrooms  accommodates  \
# 0                  1              1.0       1.0             3
# 1                  0              1.0       1.0             4
# 2                  1              1.0       1.0             4
# 3                  0              8.0       9.0            16
# 4                  1              1.0       1.0             3
#
#    review_scores_rating  review_scores_cleanliness  review_scores_checkin  \
# 0                  4.81                       4.88                   4.97
# 1                  4.56                       4.38                   4.65
# 2                  4.80                       4.82                   4.88
# 3                  4.92                       4.84                   4.97
# 4                  4.68                       4.88                   4.79
#
#    review_scores_communication  review_scores_location  review_scores_value
# 0                         4.97                    4.88                 4.82
# 1                         4.74                    4.82                 4.61
# 2                         4.91                    4.88                 4.75
# 3                         4.97                    4.83                 4.60
# 4                         4.74                    4.67                 4.72
#
# [5 rows x 28 columns]

# %%
listingsUpdate['host_id'].value_counts(10)
# Out:
# 104083974    0.006525
# 5691663      0.005662
# 2372087      0.004798
# 17638903     0.004510
# 22192546     0.004030
#                ...
# 170495540    0.000096
# 31818933     0.000096
# 182375473    0.000096
# 208094267    0.000096
# 191396323    0.000096
# Name: host_id, Length: 4486, dtype: float64

# %%
listingsUpdate['host_id'].value_counts().head(10).plot.bar()
# Out:
# <AxesSubplot:>
