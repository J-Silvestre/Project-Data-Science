# %%
#importing all the packages
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
#from xgboost import XGBRegressor
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn import linear_model as lm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_absolute_error

# %%
#importing data & merging neighbourhoods with listings
listings = pd.read_csv("listing_update/listingsUpdateOut.csv")
neighb = pd.read_csv("neighbourhoods_update/neighbourhoods_update.csv", sep = ",")
main = pd.merge(listings, neighb, how="inner", on="neighbourhood_group")

#importing data & merging previous merge with sentiment
sentiment= pd.read_csv("sentiment analysis/sentiment.csv")
sentiment= sentiment.rename(columns={"listing_id": "id"})
main2 = pd.merge(main, sentiment, how= "inner", on="id")

# %%
#selecting variables arbitrarily
data = main2[["price", "number_of_reviews",'coefficient_of_location', "host_response_rate", "population_density", "Polarity",
             "nr_of_bathrooms", "bedrooms", "review_scores_rating", "purchase_power_pc", "minimum_nights", "crime_rate_pc"]]

# %%
y = data[["price"]] #target variable
x = data[["number_of_reviews", 'coefficient_of_location', "nr_of_bathrooms", "bedrooms", "review_scores_rating", "purchase_power_pc", "crime_rate_pc", "population_density", "host_response_rate", "minimum_nights", "Polarity"]]

# %%
sns.pairplot(data, x_vars=["bedrooms", "nr_of_bathrooms", "number_of_reviews", "review_scores_rating", "host_response_rate", "Polarity"], y_vars=["price"], kind="scatter")

# %%
sns.pairplot(data, x_vars=["minimum_nights","coefficient_of_location", "purchase_power_pc", "crime_rate_pc", "population_density"], y_vars=["price"], kind="scatter")

# %%
x1 = sm.add_constant(x)
model = sm.OLS(y, x1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                 1.029e+04
# Date:                Wed, 27 Apr 2022   Prob (F-statistic):               0.00
# Time:                        17:10:35   Log-Likelihood:            -1.0281e+06
# No. Observations:              196740   AIC:                         2.056e+06
# Df Residuals:                  196728   BIC:                         2.056e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
#very interesting conclusions can be withdrawn from the table above
# regardless, now we will try to maximize the performance of our multilinear regression

#Removing outliers for all variables
# Outliers are defined as values > 3 standard deviations from mean
data = pd.DataFrame(data)
data_out = data[(np.abs(stats.zscore(data)) < 3).all(axis=1)]
data_log = np.log(data_out)
# Out:
# <ipython-input-132-bc3c63ee97e8>:8: RuntimeWarning: divide by zero encountered in log
#   data_log = np.log(data_out)
# <ipython-input-132-bc3c63ee97e8>:8: RuntimeWarning: invalid value encountered in log
#   data_log = np.log(data_out)

# %%
## Correlation Matrix 
df = pd.DataFrame(data_out)
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_9b5a2194_c644_11ec_98f7_d0c5d3b09a8erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9b5a2194_c644_11ec_98f7_d0c5d3b09a8erow0_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_9b5a2194_c644_11ec_98f7_d0c5d3b09a8erow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9b5a2194_c644_11ec_98f7_d0c5d3b09a8erow0_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_9b5a2194_c644_11ec_98f7_d0c5d3b09a8erow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_9b5a2194_c644_11ec_98f7_d0c5d3b09a8erow0_col5 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_9b5a2194_c644_11ec_98f7_d0c5d3b09a8erow0_col6 {
#             background-color:  #bcd2f7;
#             color:  #000000;
# ...

# %%
#Improving the original regression model
y = (data_out['price']) #target variable
x = data_out[['bedrooms','review_scores_rating', "Polarity"]] #predictors

# splitting training and testing data
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state=1)

#fitting the model to the training data
model = lm.LinearRegression()
model.fit(x_train, y_train)


#predicting y values
y_pred = model.predict(x_test)

# Mean Squared Error
MSE = mean_squared_error(y_test,y_pred)

#Coefficient of Determination
R2 = r2_score(y_test,y_pred)


print("The new R2: ", R2)
print("The model intercept: ", model.intercept_)
print("The model coefficients: ", model.coef_)
print("The new MSE: ", MSE)

# Y is log-transformed, but X is not --> Interpretation:
# Increasing the number of bedrooms by 1 --> Increase in the price by 27.5 euros
# Increasing review scores by 1 --> Increase in the price by 13.2 euros
# Increasing the polarity by 1 --> Increase in the price by 58.2 euros

# I think the reason why the polarity has such a big impact is because that variable only varies between 0 and 1
# Therefore, increasing it by 1 has a huge impact on how people review the listing
# Naturally, listings with very good ratings tend to be sought after more often, hence the reason why they're more expensive
# Out:
# The new R2:  0.3446382328247962
# The model intercept:  -47.52917203321614
# The model coefficients:  [27.51582639 13.23650642 58.26095036]
# The new MSE:  944.3717508889271

# %%
#I can't get this to work!!! I forgot what was the package to import to make this work

model = XGBRegressor()
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)

scores_s = (scores)**2

print('Mean MSE: %.3f (%.3f)' % (scores_s.mean(), scores.std()))

# %%
main2.dtypes
# Out:
# Unnamed: 0_x                        int64
# Unnamed: 0.1                        int64
# id                                  int64
# host_id                             int64
# neighbourhood_group                object
# neighbourhood_x                    object
# latitude                          float64
# longitude                         float64
# room_type                           int64
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# host_response_time                  int64
# host_identity_verified              int64
# host_response_rate                float64
# host_is_superhost                   int64
# nr_of_bathrooms                   float64
# bedrooms                          float64
# ...
