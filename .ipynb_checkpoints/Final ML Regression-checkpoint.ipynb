# %%
#importing all the packages
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from xgboost import XGBRegressor
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn import linear_model as lm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_absolute_error

# %%
#importing data
listings = pd.read_csv("listing_update/listingsUpdateOut.csv")
neighb = pd.read_csv("neighbourhoods_update/neighbourhoods_update.csv", sep = ",")
main = pd.merge(listings, neighb, how="inner", on="neighbourhood_group")

# %%
#selecting variables arbitrarily
data = main[["price", "number_of_reviews",'minimum_nights', "availability_365", "host_response_rate", "nr_of_bathrooms", 
             "bedrooms", "review_scores_rating", "purchase_power_pc", "crime_rate_pc", "population_density"]]

data.dtypes
# Out:
# price                     int64
# number_of_reviews         int64
# minimum_nights            int64
# availability_365          int64
# host_response_rate      float64
# nr_of_bathrooms         float64
# bedrooms                float64
# review_scores_rating    float64
# purchase_power_pc       float64
# crime_rate_pc           float64
# population_density      float64
# dtype: object

# %%
y = data[["price"]] #target variable
x = data[["number_of_reviews", "availability_365", "nr_of_bathrooms", "bedrooms", "review_scores_rating", "purchase_power_pc", "crime_rate_pc", "population_density", "host_response_rate", "minimum_nights"]]

# %%
sns.pairplot(XY, x_vars=["bedrooms", "nr_of_bathrooms", "number_of_reviews", "review_scores_rating", "host_response_rate"], y_vars=["price"], kind="scatter")

# %%
sns.pairplot(XY, x_vars=["availability_365","minimum_nights", "purchase_power_pc", "crime_rate_pc", "population_density"], y_vars=["price"], kind="scatter")

# %%
x1 = sm.add_constant(x)
model = sm.OLS(y, x1)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                 1.100e+04
# Date:                Wed, 27 Apr 2022   Prob (F-statistic):               0.00
# Time:                        12:30:04   Log-Likelihood:            -1.0294e+06
# No. Observations:              196788   AIC:                         2.059e+06
# Df Residuals:                  196777   BIC:                         2.059e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  -40.5612      1.731    -23.437      0.000     -43.953     -37.169
# number_of_reviews       -0.0431      0.001    -35.005      0.000      -0.046      -0.041
# availability_365         0.0299      0.001     35.056      0.000       0.028       0.032
# nr_of_bathrooms         12.1863      0.135     90.530      0.000      11.923      12.450
# bedrooms                25.8197      0.106    243.354      0.000      25.612      26.028
# review_scores_rating    14.7603      0.259     56.964      0.000      14.252      15.268
# purchase_power_pc        0.1897      0.025      7.655      0.000       0.141       0.238
# crime_rate_pc           -0.3069      0.098     -3.140      0.002      -0.499      -0.115
# population_density      -0.0030      0.000    -10.536      0.000      -0.004      -0.002
# host_response_rate     -20.5816      0.749    -27.473      0.000     -22.050     -19.113
# minimum_nights           0.0809      0.010      8.177      0.000       0.062       0.100
# ==============================================================================
# Omnibus:                    90919.037   Durbin-Watson:                   0.097
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          5250504.612
# Skew:                           1.436   Prob(JB):                         0.00
# Kurtosis:                      28.141   Cond. No.                     8.44e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#very interesting conclusions can be withdrawn from the table above
# regardless, now we will try to maximize the performance of our multilinear regression

#Removing outliers for all variables
# Outliers are defined as values > 3 standard deviations from mean
data = pd.DataFrame(data)
data_out = data[(np.abs(stats.zscore(data)) < 3).all(axis=1)]
data_log = np.log(data_out)
# Out:
# <ipython-input-67-bc3c63ee97e8>:8: RuntimeWarning: divide by zero encountered in log
#   data_log = np.log(data_out)

# %%
## Correlation Matrix 
df = pd.DataFrame(data_out)
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col4 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col5 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col6 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col7 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col2 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col3 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col4 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col6 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col7 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col1 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col5 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col6 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col7 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col0 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col1 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col4 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col5 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow3_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col0 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col1 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col3 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col5 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col6 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col7 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow4_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow5_col0 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow5_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow5_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow5_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_582c61d4_c61f_11ec_8b3d_d0c5d3b09a8erow5_col4 {
#             background-color:  #536edd;
#             color:  #000000

# %%
#Improving the original regression model
y = (data_log['price']) #target variable
x = data_out[['bedrooms','review_scores_rating', 'nr_of_bathrooms']] #predictors

# splitting training and testing data
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state=1)

#fitting the model to the training data
model = lm.LinearRegression()
model.fit(x_train, y_train)


#predicting y values
y_pred = model.predict(x_test)

# Mean Squared Error
MSE = mean_squared_error(y_test,y_pred)

#Coefficient of Determination
R2 = r2_score(y_test,y_pred)


print("The new R2: ", R2)
print("The model intercept: ", model.intercept_)
print("The model coefficients: ", model.coef_)
print("The new MSE: ", MSE)
# Out:
# The new R2:  0.30814908969176835
# The model intercept:  2.366677902567491
# The model coefficients:  [0.34053794 0.27379552 0.00638785]
# The new MSE:  0.1701357650749803

# %%
#I can't get this to work!!! I forgot what was the package to import to make this work

model = XGBRegressor()
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)

scores_s = (scores)**2

print('Mean MSE: %.3f (%.3f)' % (scores_s.mean(), scores.std()))
